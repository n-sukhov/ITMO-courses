# %% [markdown]
# # Практическое задание № 2. Нейронные сети

# %% [markdown]
# **Работу выполнил (а):**
#
# Сухов Николай Михайлович, id: 368876

# %% [markdown]
# ## Прогнозирование цены на жилье с помощью нейросетевой регрессионной модели
#
# Необходимо по имеющимся данным о ценах на жильё предсказать окончательную цену каждого дома с учетом характеристик домов с использованием нейронной сети. Описание набора данных  содержит 80 классов (набор переменых) классификации оценки типа жилья, и находится в файле `data_description.txt`.
#
# В работе требуется дополнить раздел «Моделирование» в подразделе «Построение и обучение модели» создать и инициализировать последовательную модель нейронной сети с помощью фрэймворков тренировки нейронных сетей как: Torch или Tensorflow. Скомпилировать нейронную сеть выбрав функцию потерь и оптимизатор соответственно. Оценить точность полученных результатов. Вывести предсказанные данные о продаже.
#
#
# ### Импорт библиотек
# Импортируем необходимые библиотеки:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
# %matplotlib widget
import warnings
warnings.filterwarnings('ignore')

# %%
import resource
soft, hard = resource.getrlimit(resource.RLIMIT_AS)
resource.setrlimit(resource.RLIMIT_AS, (14 * 1024 ** 3, hard))

# %% [markdown]
# ### Считываем набор данных
#
#
# Загрузим набор данных и присвоим следующими переменные:
#
# * `train_data`: данные, используемые для обучения модели
# * `test_data`: данные, используемые для проверки модели

# %%
train_data = pd.read_csv('data/notebook_files/train.csv')
test_data = pd.read_csv('data/notebook_files/test.csv')

# %% [markdown]
# ## Подготовка данных
# ### Отобразим обучающие и проверочные данные:

# %%
train_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
test_data.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC  Fence MiscFeature  \
# 0         Lvl    AllPub  ...         120        0    NaN  MnPrv         NaN
# 1         Lvl    AllPub  ...           0        0    NaN    NaN        Gar2
# 2         Lvl    AllPub  ...           0        0    NaN  MnPrv         NaN
# 3         Lvl    AllPub  ...           0        0    NaN    NaN         NaN
# 4         HLS    AllPub  ...         144        0    NaN    NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      6    2010        WD         Normal
# 1   12500      6    2010        WD         Normal
# 2       0      3    2010        WD         Normal
# 3       0      6    2010        WD         Normal
# 4       0      1    2010        WD         Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# Как можно видеть, `train_data` имеет на один столбец больше, чем `test_data`, это столбец `SalePrice`, для обучения модели перед применением ее для предсказания меток в test_data.

# %% [markdown]
# ### Проверяем нет ли тестовые данные пустых значений значений (Nan)
#
# Построим функцию `def missing_value_checker` для проверки и подсчёта пропущеных значений в test_data. А также выведем тип данных этих значений.

# %%
def missing_value_checker(data):
    list = []
    for feature, content in data.items():
        if data[feature].isnull().values.any():
           
            sum = data[feature].isna().sum()
            type = data[feature].dtype
            print (f'{feature}: {sum}, type: {type}')
           
            list.append(feature)
    print(list)
    print(len(list))
missing_value_checker(test_data)
# Out:
# MSZoning: 4, type: object
# LotFrontage: 227, type: float64
# Alley: 1352, type: object
# Utilities: 2, type: object
# Exterior1st: 1, type: object
# Exterior2nd: 1, type: object
# MasVnrType: 894, type: object
# MasVnrArea: 15, type: float64
# BsmtQual: 44, type: object
# BsmtCond: 45, type: object
# BsmtExposure: 44, type: object
# BsmtFinType1: 42, type: object
# BsmtFinSF1: 1, type: float64
# BsmtFinType2: 42, type: object
# BsmtFinSF2: 1, type: float64
# BsmtUnfSF: 1, type: float64
# TotalBsmtSF: 1, type: float64
# BsmtFullBath: 2, type: float64
# BsmtHalfBath: 2, type: float64
# KitchenQual: 1, type: object
# Functional: 2, type: object
# FireplaceQu: 730, type: object
# GarageType: 76, type: object
# GarageYrBlt: 78, type: float64
# GarageFinish: 78, type: object
# GarageCars: 1, type: float64
# GarageArea: 1, type: float64
# GarageQual: 78, type: object
# GarageCond: 78, type: object
# PoolQC: 1456, type: object
# Fence: 1169, type: object
# MiscFeature: 1408, type: object
# SaleType: 1, type: object
# ['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType']
# 33

# %% [markdown]
# Проверяем какие признаки в таблице можно оставить, а какие удалить. Если пропущенных значений слишком много, то удалим признак. Если их небольшое количество, то заполним `mean` или `median` для чисел, новая категория `missing` для строковых объектов.
#
# В соответствии с этим:
#
# – удалим ['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'];
#
# – заполним числовое отсутствующее значение значением `mean`;
#
# – заполним строковое отсутствующее значение значением `missing`.

# %%
test_edited = test_data.drop(['Alley','FireplaceQu','PoolQC', 'Fence', 'MiscFeature'], axis=1)
train_edited = train_data.drop(['Alley','FireplaceQu','PoolQC', 'Fence', 'MiscFeature'], axis=1)

def nan_filler(data):
    for label, content in data.items():
        if pd.api.types.is_numeric_dtype(content):
            data[label] = content.fillna(content.median())
        else:
            data[label] = content.astype("category").cat.as_ordered()
            data[label] = pd.Categorical(content).codes+1

nan_filler(test_edited)
nan_filler(train_edited)

# %% [markdown]
# ### Перепроверим наши данные:

# %%
missing_value_checker(test_edited)
# Out:
# []
# 0

# %%
missing_value_checker(train_edited)
# Out:
# []
# 0

# %%
train_edited.shape, test_edited.shape
# Out:
# ((1460, 76), (1459, 75))

# %%
test_edited.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1459 entries, 0 to 1458
# Data columns (total 75 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1459 non-null   int64
#  1   MSSubClass     1459 non-null   int64
#  2   MSZoning       1459 non-null   int8
#  3   LotFrontage    1459 non-null   float64
#  4   LotArea        1459 non-null   int64
#  5   Street         1459 non-null   int8
#  6   LotShape       1459 non-null   int8
#  7   LandContour    1459 non-null   int8
#  8   Utilities      1459 non-null   int8
#  9   LotConfig      1459 non-null   int8
#  10  LandSlope      1459 non-null   int8
#  11  Neighborhood   1459 non-null   int8
#  12  Condition1     1459 non-null   int8
#  13  Condition2     1459 non-null   int8
#  14  BldgType       1459 non-null   int8
#  15  HouseStyle     1459 non-null   int8
#  16  OverallQual    1459 non-null   int64
#  17  OverallCond    1459 non-null   int64
#  18  YearBuilt      1459 non-null   int64
#  19  YearRemodAdd   1459 non-null   int64
#  20  RoofStyle      1459 non-null   int8
#  21  RoofMatl       1459 non-null   int8
#  22  Exterior1st    1459 non-null   int8
#  23  Exterior2nd    1459 non-null   int8
#  24  MasVnrType     1459 non-null   int8
#  25  MasVnrArea     1459 non-null   float64
#  26  ExterQual      1459 non-null   int8
#  27  ExterCond      1459 non-null   int8
#  28  Foundation     1459 non-null   int8
#  29  BsmtQual       1459 non-null   int8
#  30  BsmtCond       1459 non-null   int8
#  31  BsmtExposure   1459 non-null   int8
#  32  BsmtFinType1   1459 non-null   int8
#  33  BsmtFinSF1     1459 non-null   float64
#  34  BsmtFinType2   1459 non-null   int8
#  35  BsmtFinSF2     1459 non-null   float64
#  36  BsmtUnfSF      1459 non-null   float64
#  37  TotalBsmtSF    1459 non-null   float64
#  38  Heating        1459 non-null   int8
#  39  HeatingQC      1459 non-null   int8
#  40  CentralAir     1459 non-null   int8
#  41  Electrical     1459 non-null   int8
#  42  1stFlrSF       1459 non-null   int64
#  43  2ndFlrSF       1459 non-null   int64
#  44  LowQualFinSF   1459 non-null   int64
#  45  GrLivArea      1459 non-null   int64
#  46  BsmtFullBath   1459 non-null   float64
#  47  BsmtHalfBath   1459 non-null   float64
#  48  FullBath       1459 non-null   int64
#  49  HalfBath       1459 non-null   int64
#  50  BedroomAbvGr   1459 non-null   int64
#  51  KitchenAbvGr   1459 non-null   int64
#  52  KitchenQual    1459 non-null   int8
#  53  TotRmsAbvGrd   1459 non-null   int64
#  54  Functional     1459 non-null   int8
#  55  Fireplaces     1459 non-null   int64
#  56  GarageType     1459 non-null   int8
#  57  GarageYrBlt    1459 non-null   float64
#  58  GarageFinish   1459 non-null   int8
#  59  GarageCars     1459 non-null   float64
#  60  GarageArea     1459 non-null   float64
#  61  GarageQual     1459 non-null   int8
#  62  GarageCond     1459 non-null   int8
#  63  PavedDrive     1459 non-null   int8
#  64  WoodDeckSF     1459 non-null   int64
#  65  OpenPorchSF    1459 non-null   int64
#  66  EnclosedPorch  1459 non-null   int64
#  67  3SsnPorch      1459 non-null   int64
#  68  ScreenPorch    1459 non-null   int64
#  69  PoolArea       1459 non-null   int64
#  70  MiscVal        1459 non-null   int64
#  71  MoSold         1459 non-null   int64
#  72  YrSold         1459 non-null   int64
#  73  SaleType       1459 non-null   int8
#  74  SaleCondition  1459 non-null   int8
# dtypes: float64(11), int64(26), int8(38)
# memory usage: 476.0 KB

# %%
train_edited.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 76 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   int8
#  3   LotFrontage    1460 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   int8
#  6   LotShape       1460 non-null   int8
#  7   LandContour    1460 non-null   int8
#  8   Utilities      1460 non-null   int8
#  9   LotConfig      1460 non-null   int8
#  10  LandSlope      1460 non-null   int8
#  11  Neighborhood   1460 non-null   int8
#  12  Condition1     1460 non-null   int8
#  13  Condition2     1460 non-null   int8
#  14  BldgType       1460 non-null   int8
#  15  HouseStyle     1460 non-null   int8
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
#  18  YearBuilt      1460 non-null   int64
#  19  YearRemodAdd   1460 non-null   int64
#  20  RoofStyle      1460 non-null   int8
#  21  RoofMatl       1460 non-null   int8
#  22  Exterior1st    1460 non-null   int8
#  23  Exterior2nd    1460 non-null   int8
#  24  MasVnrType     1460 non-null   int8
#  25  MasVnrArea     1460 non-null   float64
#  26  ExterQual      1460 non-null   int8
#  27  ExterCond      1460 non-null   int8
#  28  Foundation     1460 non-null   int8
#  29  BsmtQual       1460 non-null   int8
#  30  BsmtCond       1460 non-null   int8
#  31  BsmtExposure   1460 non-null   int8
#  32  BsmtFinType1   1460 non-null   int8
#  33  BsmtFinSF1     1460 non-null   int64
#  34  BsmtFinType2   1460 non-null   int8
#  35  BsmtFinSF2     1460 non-null   int64
#  36  BsmtUnfSF      1460 non-null   int64
#  37  TotalBsmtSF    1460 non-null   int64
#  38  Heating        1460 non-null   int8
#  39  HeatingQC      1460 non-null   int8
#  40  CentralAir     1460 non-null   int8
#  41  Electrical     1460 non-null   int8
#  42  1stFlrSF       1460 non-null   int64
#  43  2ndFlrSF       1460 non-null   int64
#  44  LowQualFinSF   1460 non-null   int64
#  45  GrLivArea      1460 non-null   int64
#  46  BsmtFullBath   1460 non-null   int64
#  47  BsmtHalfBath   1460 non-null   int64
#  48  FullBath       1460 non-null   int64
#  49  HalfBath       1460 non-null   int64
#  50  BedroomAbvGr   1460 non-null   int64
#  51  KitchenAbvGr   1460 non-null   int64
#  52  KitchenQual    1460 non-null   int8
#  53  TotRmsAbvGrd   1460 non-null   int64
#  54  Functional     1460 non-null   int8
#  55  Fireplaces     1460 non-null   int64
#  56  GarageType     1460 non-null   int8
#  57  GarageYrBlt    1460 non-null   float64
#  58  GarageFinish   1460 non-null   int8
#  59  GarageCars     1460 non-null   int64
#  60  GarageArea     1460 non-null   int64
#  61  GarageQual     1460 non-null   int8
#  62  GarageCond     1460 non-null   int8
#  63  PavedDrive     1460 non-null   int8
#  64  WoodDeckSF     1460 non-null   int64
#  65  OpenPorchSF    1460 non-null   int64
#  66  EnclosedPorch  1460 non-null   int64
#  67  3SsnPorch      1460 non-null   int64
#  68  ScreenPorch    1460 non-null   int64
#  69  PoolArea       1460 non-null   int64
#  70  MiscVal        1460 non-null   int64
#  71  MoSold         1460 non-null   int64
#  72  YrSold         1460 non-null   int64
#  73  SaleType       1460 non-null   int8
#  74  SaleCondition  1460 non-null   int8
#  75  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), int8(38)
# memory usage: 487.7 KB

# %% [markdown]
# ### Разделим данные
#
# Поскольку мы не знаем метку (Цена) тестовых данных, для оценки модели, чтобы получить лучшую модель перед прогнозированием тестовых данных, разделим данные в файле train.scv на обучающие и проверочные данные, соотношение составляет 20%.

# %%
X = train_edited.drop('SalePrice', axis=1)
y = train_edited['SalePrice']

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size = 0.2)

# %%
X_train.shape, test_edited.shape
# Out:
# ((1168, 75), (1459, 75))

# %% [markdown]
# ## Моделирование

# %% [markdown]
# ### Построение и обучение модели

# %% [markdown]
# Создайте последовательную модель нейронной сети с помощью фрэймворков тренировки нейронных сетей как: Torch или Tensorflow.

# %%
from tensorflow import keras
from tensorflow.keras import layers
from sklearn.model_selection import GridSearchCV
import tensorflow as tf
import numpy as np
import warnings
warnings.filterwarnings('ignore')
tf.random.set_seed(40)
# Out:
# 2025-11-26 16:50:06.075658: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:06.087175: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:06.473369: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:50:07.923384: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:07.925518: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
# Создаем обертку для использования с GridSearchCV
class KerasGS:
    def __init__(self, units1=64, units2=32, activation='relu', optimizer='adam', epochs=100, batch_size=32, loss='mse'):
        self.units1 = units1
        self.units2 = units2
        self.activation = activation
        self.optimizer = optimizer
        self.epochs = epochs
        self.batch_size = batch_size
        self.loss = loss
        
    def create_model(self):
        model = keras.Sequential([
            layers.Dense(self.units1, activation=self.activation, input_shape=(X_train.shape[1],)),
            layers.Dense(self.units2, activation=self.activation),
            layers.Dense(1, activation='linear')
        ])
        
        model.compile(
            optimizer=self.optimizer,
            loss=self.loss,
            metrics=['mae']
        )
        return model
        
    def get_params(self, deep=True):
        return {
            'units1': self.units1,
            'units2': self.units2,
            'activation': self.activation,
            'optimizer': self.optimizer,
            'epochs': self.epochs,
            'batch_size': self.batch_size,
            'loss': self.loss
        }
        
    def set_params(self, **params):
        for key, value in params.items():
            setattr(self, key, value)
        return self
        
    def fit(self, X, y):
        self.model_ = self.create_model()
        self.history_ = self.model_.fit(
            X, y,
            epochs=self.epochs,
            batch_size=self.batch_size,
            verbose=0
        )
        return self
        
    def predict(self, X):
        return self.model_.predict(X)
        
    def score(self, X, y):
        loss = self.model_.evaluate(X, y, verbose=0)[0]
        return -loss

# %%
# Набор параметров
param_grid = {
    'units1': [64, 128, 256, 512],
    'units2': [128, 256, 512], 
    'activation': ['relu', 'linear', 'sigmoid'],
    'optimizer': ['adam', 'sgd'],
    'epochs': [40],
    'batch_size': [16, 32, 64],
    'loss': ['mse', 'mape']
}
base_model = KerasGS()

grid = GridSearchCV(
    estimator=base_model,
    param_grid=param_grid,
    cv=2,
    scoring='neg_mean_squared_error',
    n_jobs=-1,
    verbose=1
)

# Обучаем
grid_result = grid.fit(X_train.values, y_train.values)
# Out:
# Fitting 2 folds for each of 432 candidates, totalling 864 fits
# 2025-11-26 16:50:09.952160: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:09.952489: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:10.007940: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:50:10.561811: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:10.562617: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:10.612680: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:10.613013: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:10.622804: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:50:10.623360: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:10.623755: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:10.633409: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:10.633880: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:10.654328: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:10.654691: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:10.683821: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:50:10.690786: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:50:10.703960: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:50:10.714144: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:50:10.788894: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:10.789233: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:10.848014: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:50:11.148624: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:11.148981: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:11.215319: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:50:11.829438: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:11.829974: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:12.382084: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:12.383843: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:12.434056: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:12.435117: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:12.467141: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:12.467890: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:12.629052: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:12.629814: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:12.647787: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:12.649005: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:50:12.794015: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:12.795230: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165012.820661    7516 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165012.834956    7516 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-26 16:50:12.959645: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:50:12.960714: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165013.260026    7530 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165013.265874    7530 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165013.308339    7519 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165013.313013    7519 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165013.371656    7518 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165013.377093    7518 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165013.462306    7517 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165013.472717    7517 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165013.579978    7526 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165013.583766    7526 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165013.720620    7515 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165013.726041    7515 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165013.818498    7520 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165013.822976    7520 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/stepe
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step p
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step e
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step e
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/stepe
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/stepep
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/stepep
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2025-11-26 16:55:29.431589: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:29.431972: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:29.490226: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-26 16:55:31.016857: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:31.017413: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2025-11-26 16:55:31.436430: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:31.436782: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:31.498311: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165331.853334  245056 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165331.860250  245056 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2025-11-26 16:55:33.223667: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:33.224040: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:33.617007: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:33.617372: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:33.678393: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165334.068509  246698 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165334.075190  246698 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-26 16:55:35.484496: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:35.485071: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:35.871818: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:35.872458: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:35.936564: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165336.350109  248768 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165336.357610  248768 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2025-11-26 16:55:37.567720: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:37.568248: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165338.417420  250497 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165338.421806  250497 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2025-11-26 16:55:41.239127: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:41.239514: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:41.307842: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2025-11-26 16:55:42.973338: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:42.973872: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165343.808379  256949 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165343.813083  256949 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2025-11-26 16:55:46.304120: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:46.304360: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:46.356681: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2025-11-26 16:55:47.995355: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:47.998133: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:48.374253: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:48.375268: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:48.444016: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165348.823762  262583 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165348.828472  262583 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-26 16:55:50.879437: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:50.881164: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:51.580320: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 16:55:51.582825: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:51.747992: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165352.694795  264364 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165352.701716  264364 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-26 16:55:55.361711: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 16:55:55.364913: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165357.521040  265895 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165357.534455  265895 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# ...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/stepep
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2025-11-26 17:04:58.909002: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 17:04:58.909492: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:04:58.965234: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# 2025-11-26 17:05:01.747042: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:01.747648: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2025-11-26 17:05:02.522903: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 17:05:02.523391: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:02.580301: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165902.959919  719703 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165902.968400  719703 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2025-11-26 17:05:04.685410: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:04.685956: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 17:05:05.086418: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 17:05:05.086725: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:05.151182: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165905.469743  721906 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165905.472979  721906 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-26 17:05:06.791363: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:06.791939: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 17:05:07.535401: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 17:05:07.535929: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:07.611035: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165907.690393  723603 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165907.693737  723603 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 2025-11-26 17:05:09.179472: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:09.180000: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 17:05:09.567189: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 17:05:09.567536: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:09.629877: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165910.079624  724869 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165910.083699  724869 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 2025-11-26 17:05:11.540659: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:11.541403: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165912.587774  726742 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165912.595179  726742 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2025-11-26 17:05:13.477185: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-11-26 17:05:13.480654: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:13.570992: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 2025-11-26 17:05:15.651929: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-11-26 17:05:15.656590: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165916.789853  729083 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165916.799716  729083 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/stepp
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1764165936.881634    7266 cuda_executor.cc:1309] INTERNAL: CUDA Runtime error: Failed call to cudaGetRuntimeVersion: Error loading CUDA libraries. GPU will not be used.: Error loading CUDA libraries. GPU will not be used.
# W0000 00:00:1764165936.885363    7266 gpu_device.cc:2342] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
print("Лучшие параметры:", grid_result.best_params_)
print("Лучший score:", grid_result.best_score_)
# Out:
# Лучшие параметры: {'activation': 'relu', 'batch_size': 16, 'epochs': 40, 'loss': 'mape', 'optimizer': 'adam', 'units1': 512, 'units2': 256}
# Лучший score: -1945489152.0

# %%
results_df = pd.DataFrame(grid_result.cv_results_)

# %% [markdown]
# #### Анализ влияния units1 (нейроны в первом слое)

# %%
plt.figure(figsize=(10, 6))
units1_scores = results_df.groupby('param_units1')['mean_test_score'].mean()
plt.bar([str(x) for x in units1_scores.index], -units1_scores.values)
plt.title('Влияние количества нейронов в первом слое на MSE')
plt.xlabel('Количество нейронов')
plt.ylabel('MSE')
for i, v in enumerate(-units1_scores.values):
    plt.text(i, v + 0.1, f'{v:.1f}', ha='center', fontweight='bold')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Анализ влияния units2 (нейроны во втором слое)

# %%
plt.figure(figsize=(10, 6))
units1_scores = results_df.groupby('param_units2')['mean_test_score'].mean()
plt.bar([str(x) for x in units1_scores.index], -units1_scores.values)
plt.title('Влияние количества нейронов во втором слое на MSE')
plt.xlabel('Количество нейронов')
plt.ylabel('MSE')
for i, v in enumerate(-units1_scores.values):
    plt.text(i, v + 0.1, f'{v:.1f}', ha='center', fontweight='bold')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Анализ влияния batch_size

# %%
plt.figure(figsize=(10, 6))
batch_scores = results_df.groupby('param_batch_size')['mean_test_score'].mean()
plt.bar([str(x) for x in batch_scores.index], -batch_scores.values)
plt.title('Влияние batch_size на MSE')
plt.xlabel('Batch Size')
plt.ylabel('MSE')
for i, v in enumerate(-batch_scores.values):
    plt.text(i, v + 0.1, f'{v:.1f}', ha='center', fontweight='bold')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Анализ влияния функции активации

# %%
plt.figure(figsize=(8, 6))
activation_scores = results_df.groupby('param_activation')['mean_test_score'].mean()
plt.bar(activation_scores.index, -activation_scores.values)
plt.title('Влияние функции активации на MSE')
plt.xlabel('Функция активации')
plt.ylabel('MSE')
for i, v in enumerate(-activation_scores.values):
    plt.text(i, v + 0.1, f'{v:.1f}', ha='center', fontweight='bold')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Анализ влияния оптимизатора

# %%
plt.figure(figsize=(8, 6))
optimizer_scores = results_df.groupby('param_optimizer')['mean_test_score'].mean()
plt.bar(optimizer_scores.index, -optimizer_scores.values)
plt.title('Влияние оптимизатора на MSE')
plt.xlabel('Оптимизатор')
plt.ylabel('MSE')
for i, v in enumerate(-optimizer_scores.values):
    plt.text(i, v + 0.1, f'{v:.1f}', ha='center', fontweight='bold')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Влияние функции потерь на MSE

# %%
plt.figure(figsize=(8, 6))
loss_scores = results_df.groupby('param_loss')['mean_test_score'].mean()
plt.bar(loss_scores.index, -loss_scores.values)
plt.title('Влияние функции потерь на MSE')
plt.xlabel('Функция потерь')
plt.ylabel('MSE')
for i, v in enumerate(-loss_scores.values):
    plt.text(i, v + 0.1, f'{v:.1f}', ha='center', fontweight='bold')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Скомпилируйте нейронную сеть, выбрав функцию потерь и оптимизатор соответственно.

# %%
best_params = grid_result.best_params_
final_model = keras.Sequential([
    layers.Dense(best_params['units1'], activation=best_params['activation'], input_shape=(X_train.shape[1],)),
    layers.Dense(best_params['units2'], activation=best_params['activation']),
    layers.Dense(1, activation='linear')
])

final_model.compile(
    optimizer=best_params['optimizer'],
    loss='mse',
    metrics=['mae']
)

# %% [markdown]
# Обучите модель на обучающих данных `X_train` и `y_train` задав гиперпараметры вашей модели нейронной сети, например количество эпох (epochs), размер мини-выборки (batch_size) и другие.

# %%
history = final_model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=best_params['epochs'],
    batch_size=best_params['batch_size'],
    verbose=1
)
# Out:
# Epoch 1/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 16507667456.0000 - mae: 90986.8594 - val_loss: 4218842368.0000 - val_mae: 43495.2227
# Epoch 2/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5700876800.0000 - mae: 45848.6523 - val_loss: 3361672960.0000 - val_mae: 42153.7305
# Epoch 3/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 3534373120.0000 - mae: 41016.9023 - val_loss: 3013494272.0000 - val_mae: 39692.3750
# Epoch 4/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2857299712.0000 - mae: 36743.9844 - val_loss: 2634178560.0000 - val_mae: 35790.4219
# Epoch 5/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2419957760.0000 - mae: 32731.4180 - val_loss: 2359742976.0000 - val_mae: 32235.1230
# Epoch 6/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 2167538944.0000 - mae: 30100.7539 - val_loss: 2235051264.0000 - val_mae: 30289.7676
# Epoch 7/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 2061295488.0000 - mae: 28960.8965 - val_loss: 2198929664.0000 - val_mae: 29474.7676
# Epoch 8/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2021726592.0000 - mae: 28605.0137 - val_loss: 2181477888.0000 - val_mae: 29142.5215
# Epoch 9/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1996564736.0000 - mae: 28416.0312 - val_loss: 2171298560.0000 - val_mae: 29002.3633
# Epoch 10/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1977573248.0000 - mae: 28260.1152 - val_loss: 2156447232.0000 - val_mae: 28819.9316
# Epoch 11/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1959916928.0000 - mae: 28129.9062 - val_loss: 2143798656.0000 - val_mae: 28690.1191
# Epoch 12/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1945464448.0000 - mae: 28029.3086 - val_loss: 2133446784.0000 - val_mae: 28581.6035
# Epoch 13/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1932141056.0000 - mae: 27935.6465 - val_loss: 2123971712.0000 - val_mae: 28501.9883
# Epoch 14/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1919693312.0000 - mae: 27854.2363 - val_loss: 2112697472.0000 - val_mae: 28385.8516
# Epoch 15/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1907388928.0000 - mae: 27775.2090 - val_loss: 2102264960.0000 - val_mae: 28289.3105
# Epoch 16/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1895500672.0000 - mae: 27700.1406 - val_loss: 2091359232.0000 - val_mae: 28207.0820
# Epoch 17/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1883300224.0000 - mae: 27624.7871 - val_loss: 2078758400.0000 - val_mae: 28119.0488
# Epoch 18/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 1871074048.0000 - mae: 27546.7969 - val_loss: 2067244032.0000 - val_mae: 28052.5625
# Epoch 19/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1858317952.0000 - mae: 27460.8516 - val_loss: 2055783936.0000 - val_mae: 27970.2188
# Epoch 20/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1846067328.0000 - mae: 27387.1152 - val_loss: 2044288512.0000 - val_mae: 27901.0703
# Epoch 21/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1833116288.0000 - mae: 27303.8340 - val_loss: 2034711168.0000 - val_mae: 27806.5918
# Epoch 22/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1821474432.0000 - mae: 27235.2227 - val_loss: 2022213632.0000 - val_mae: 27757.0254
# Epoch 23/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1807506560.0000 - mae: 27120.7090 - val_loss: 2013709696.0000 - val_mae: 27648.5312
# Epoch 24/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1796765440.0000 - mae: 27052.8125 - val_loss: 2003725312.0000 - val_mae: 27635.8105
# Epoch 25/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1783851136.0000 - mae: 26970.6289 - val_loss: 1992711680.0000 - val_mae: 27559.9492
# Epoch 26/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1773907968.0000 - mae: 26906.7129 - val_loss: 1982907264.0000 - val_mae: 27495.8711
# Epoch 27/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1760895232.0000 - mae: 26828.8262 - val_loss: 1973398016.0000 - val_mae: 27403.4102
# Epoch 28/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1750149504.0000 - mae: 26760.4180 - val_loss: 1966579584.0000 - val_mae: 27332.1387
# Epoch 29/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1741075200.0000 - mae: 26710.4238 - val_loss: 1954007040.0000 - val_mae: 27321.9512
# Epoch 30/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1727892224.0000 - mae: 26631.8164 - val_loss: 1947347200.0000 - val_mae: 27243.0371
# Epoch 31/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1718639744.0000 - mae: 26569.5918 - val_loss: 1937173504.0000 - val_mae: 27181.5625
# Epoch 32/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1705917696.0000 - mae: 26476.2383 - val_loss: 1928043264.0000 - val_mae: 27102.6484
# Epoch 33/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1695218816.0000 - mae: 26421.8691 - val_loss: 1919154688.0000 - val_mae: 27071.3047
# Epoch 34/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1686060544.0000 - mae: 26368.7363 - val_loss: 1904177152.0000 - val_mae: 26989.8418
# Epoch 35/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1670934016.0000 - mae: 26264.8867 - val_loss: 1905178880.0000 - val_mae: 26921.7676
# Epoch 36/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 1662749824.0000 - mae: 26227.0527 - val_loss: 1885111168.0000 - val_mae: 26828.3105
# Epoch 37/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1652937344.0000 - mae: 26163.8691 - val_loss: 1877788928.0000 - val_mae: 26770.1602
# Epoch 38/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1639142272.0000 - mae: 26086.3008 - val_loss: 1870950272.0000 - val_mae: 26707.7793
# Epoch 39/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 1630443264.0000 - mae: 26048.1289 - val_loss: 1857273344.0000 - val_mae: 26650.1699
# Epoch 40/40
# 73/73 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1617630464.0000 - mae: 25965.2324 - val_loss: 1848922368.0000 - val_mae: 26584.4434

# %% [markdown]
# #### Анализ влияния количества эпох

# %%
plt.figure(figsize=(8, 10))

plt.subplot(2, 1, 1)
plt.plot(history.history['loss'], label='Training Loss', linewidth=2)
plt.plot(history.history['val_loss'], label='Validation Loss', linewidth=2)
plt.title('MSE')
plt.xlabel('Эпоха')
plt.ylabel('Loss')
plt.legend()
plt.grid(True, alpha=0.3)

plt.subplot(2, 1, 2)
plt.plot(history.history['mae'], label='Training MAE', linewidth=2)
plt.plot(history.history['val_mae'], label='Validation MAE', linewidth=2)
plt.title('MAE')
plt.xlabel('Эпоха')
plt.ylabel('MAE')
plt.legend()
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# **Оцените полученные результаты**

# %%
scores = final_model.evaluate(X_val, y_val, verbose=0)
print(f"\nРезультаты лучшей модели на валидационной выборке:")
print(f"Loss (MSE): {scores[0]:.2f}")
print(f"MAE: {scores[1]:.2f}")
# Out:
# Результаты лучшей модели на валидационной выборке:
# Loss (MSE): 1848922496.00
# MAE: 26584.45

# %% [markdown]
# ### Прогнозирование

# %%
preds = final_model.predict(test_edited)
preds = preds.flatten()
# Out:
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %%
output = pd.DataFrame({
    'Id': test_data['Id'],
    'SalePrice': preds
})

print(output.head(10))
# Out:
#      Id      SalePrice
# 0  1461  159976.687500
# 1  1462  129088.992188
# 2  1463  199397.765625
# 3  1464  197550.109375
# 4  1465  176137.031250
# 5  1466  177047.328125
# 6  1467  182705.125000
# 7  1468  153475.640625
# 8  1469  182317.281250
# 9  1470  146718.656250

# %% [markdown]
# ## Задание
#
#
# В задние представлено логика выполнения с использование tensorflow/keras. Выполнять можно как с использованием tensorflow/keras, так и pytorch.
#
#
# **При выполнении:**
#
# Выведите отчет нейросетевой регрессионной модели, для  прогнозирование цены на жилье.
#
#
# Подберите  разные комбинации гиперпараметров таким образом, чтобы получить лучший результат на тестовом наборе данных.
#
# Попробуйте использовать разное количество нейронов на входном слое. Опишите достигнутый результат.
#
# Добавьте в нейронную сеть скрытый слой с разным количеством нейронов.
#
# Используйте разное количество эпох. Опишите достигнутый результат.
#
# Используйте разные размеры мини-выборки (batch_size). Опишите достигнутый результат.
#
# Попробуйте использовать разные значения оптимизатора `optimizers` и функции потерь `loss`. Сравните полученные результаты.
#
# **Вопросы:**
#
# Как выше перечисленные параметры влияют на полученный вами результат?
#
# Что такое эпоха (Epoch)? В чем отличие от итерации (Iteration)?
#
# Что такое функция активации? Какие вам известны? Как и зачем используются в нейронной сети?
#
# Что такое MSE(Mean Squared Error) - Средняя квадратичная ошибка? Что такое MAE(Mean Absolute Error)? Для чего используются.
